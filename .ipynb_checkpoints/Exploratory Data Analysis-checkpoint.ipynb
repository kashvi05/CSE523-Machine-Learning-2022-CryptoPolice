# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
# Standard global variables

SEED_VALUE = 42
color = ['r', 'g', 'b']
color_count = 0

# %%
# Read CompressedData - Output of preprocessing notebook
X_train = pd.read_csv("./Dataset/CompressedData.csv")
X_train.head()
# Out:
#       Count      Open      High       Low     Close    Volume      VWAP  \
# 0 -0.420178 -0.231602 -0.231818 -0.231463 -0.231600 -0.163735 -0.231575
# 1 -0.406696 -0.231558 -0.231774 -0.231420 -0.231556 -0.163475 -0.231531
# 2 -0.412850 -0.231527 -0.231744 -0.231389 -0.231525 -0.163609 -0.231500
# 3 -0.411005 -0.231471 -0.231686 -0.231333 -0.231469 -0.163602 -0.231444
# 4 -0.389464 -0.230984 -0.231194 -0.230852 -0.230981 -0.162833 -0.230957
#
#      new_date  Asset_ID    Target
# 0  2018-01-01         0  0.000148
# 1  2018-01-02         0  0.000393
# 2  2018-01-03         0  0.000549
# 3  2018-01-04         0  0.000006
# 4  2018-01-05         0  0.005618

# %%
# Correlation heatmap
sns.heatmap(X_train.corr(), cmap='YlGnBu', annot=True)
plt.show()

# %% [markdown]
# ## Interpretations
# * Correlation between open, high, low, close and VWAP are perfectly correlated.
# * This means that there is some linear dependence between these features.
# * Therefore, we can drop these columns safely with minimal loss of information (ideally none).
# * This step will be performed in Feature Engineering.

# %%
# Scatter Plot of each variable with Target
for feature in X_train.columns:
    if feature not in ['Target', "Asset_ID", "new_date"]:
        sns.scatterplot(data=X_train, x=feature, y="Target", color=color[color_count % 3])
        color_count += 1
    plt.show()

# %%
# Outliers detection using box plot
for feature in X_train.columns:
    if feature not in ['new_date', 'Asset_ID']:
        sns.boxplot(X_train[feature], color=color[color_count % 3])
        plt.show()
        color_count += 1
# Out:
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Interpretations
# * There are outliers in Count, Volume and Target features.
# * These outliers will be taken care of in the Feature Engineering notebook

# %%
# Histogram plots for each features
for feature in X_train.columns:
    if feature not in ['new_date', 'Asset_ID']:
        sns.distplot(X_train[feature], kde=True, color = color[color_count % 3])
        color_count += 1
        plt.xlabel(feature)
        plt.ylabel("Count")
        plt.show()
# Out:
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/sameep/.local/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Lag features and its correlation
# This is also a part of feature engineering

for i in range(0, 7):
    lag_column_name = 'lag_' + str(i)
    X_train[lag_column_name] = X_train['Target'].shift(i)

X_train.head(10)
# Out:
#       Count      Open      High       Low     Close    Volume      VWAP  \
# 0 -0.420178 -0.231602 -0.231818 -0.231463 -0.231600 -0.163735 -0.231575
# 1 -0.406696 -0.231558 -0.231774 -0.231420 -0.231556 -0.163475 -0.231531
# 2 -0.412850 -0.231527 -0.231744 -0.231389 -0.231525 -0.163609 -0.231500
# 3 -0.411005 -0.231471 -0.231686 -0.231333 -0.231469 -0.163602 -0.231444
# 4 -0.389464 -0.230984 -0.231194 -0.230852 -0.230981 -0.162833 -0.230957
# 5 -0.372375 -0.229968 -0.230173 -0.229845 -0.229966 -0.162677 -0.229942
# 6 -0.394994 -0.229556 -0.229767 -0.229424 -0.229555 -0.163355 -0.229530
# 7 -0.390812 -0.229978 -0.230189 -0.229846 -0.229976 -0.163112 -0.229952
# 8 -0.397352 -0.229901 -0.230114 -0.229766 -0.229900 -0.163455 -0.229875
# 9 -0.396667 -0.230235 -0.230448 -0.230100 -0.230234 -0.163513 -0.230208
#
#      new_date  Asset_ID    Target     lag_0     lag_1     lag_2     lag_3  \
# 0  2018-01-01         0  0.000148  0.000148       NaN       NaN       NaN
# 1  2018-01-02         0  0.000393  0.000393  0.000148       NaN       NaN
# 2  2018-01-03         0  0.000549  0.000549  0.000393  0.000148       NaN
# 3  2018-01-04         0  0.000006  0.000006  0.000549  0.000393  0.000148
# 4  2018-01-05         0  0.005618  0.005618  0.000006  0.000549  0.000393
# 5  2018-01-06         0  0.004518  0.004518  0.005618  0.000006  0.000549
# 6  2018-01-07         0 -0.001542 -0.001542  0.004518  0.005618  0.000006
# 7  2018-01-08         0 -0.000125 -0.000125 -0.001542  0.004518  0.005618
# 8  2018-01-09         0 -0.000508 -0.000508 -0.000125 -0.001542  0.004518
# 9  2018-01-10         0  0.000403  0.000403 -0.000508 -0.000125 -0.001542
#
#       lag_4     lag_5     lag_6
# 0       NaN       NaN       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
# 4  0.000148       NaN       NaN
# 5  0.000393  0.000148       NaN
# 6  0.000549  0.000393  0.000148
# 7  0.000006  0.000549  0.000393
# 8  0.005618  0.000006  0.000549
# 9  0.004518  0.005618  0.000006

# %%
# How is lag feature related with target. Correlation is used
plt.figure(figsize=(15, 10))
sns.heatmap(X_train.corr(), annot = True, cmap='YlGnBu')
plt.show()

# %% [markdown]
# ## Interpretations
# * Lag features are not at all correlated or do not exhibit any relationship with Target.
# * From this we can conclude that even if we consider lag features then, there is very little possibility that the performance of the model will improve.
# * Further, one thing to note is that lag0 and Target have a correlation of 1.
# * This is because lag 0 implies that we are not shifting the dataset and hence lag0 and Target are one and the same thing.

# %%
# Sesonality for cryptocurrencies

for feature in X_train.columns:
    if feature not in ['Target', 'Asset_ID']:
        title = feature + " vs Target"
        plt.title(title)
        sns.scatterplot(data=X_train, y=feature, x='Target',color = color[color_count % 3])
        plt.xlabel(feature)
        plt.ylabel("Target")
        color_count += 1
        plt.show()
