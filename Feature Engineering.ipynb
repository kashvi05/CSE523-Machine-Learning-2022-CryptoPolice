# %%
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("./Dataset/CompressedData.csv")
X_train.head()
# Out:
#    Asset_ID      Count       Open       High        Low      Close  \
# 0         0  12.935323   8.271426   8.281705   8.259240   8.269135
# 1         0  20.910552   8.526834   8.540125   8.510583   8.525199
# 2         0  17.171209   8.706437   8.718355   8.692207   8.704740
# 3         0  20.150885   9.032841   9.052548   9.014046   9.032460
# 4         0  31.315202  11.874380  11.924612  11.813422  11.875316
#
#         Volume       VWAP    Target    new_date
# 0   464.922075   8.269348  0.000148  2018-01-01
# 1   882.242788   8.524557  0.000393  2018-01-02
# 2   662.049371   8.704213  0.000549  2018-01-03
# 3   742.490331   9.032244  0.000006  2018-01-04
# 4  1928.156932  11.870353  0.005618  2018-01-05

# %%
Asset_ID = list(range(0, 14))
for id in Asset_ID:
    temp = "./Dataset/Asset_ID_" + str(id)
    lag_train = pd.read_csv(temp)
    plt.figure(figsize=(10, 5))
    sns.heatmap(lag_train.corr(),cmap = "YlGnBu",annot = True)
    plt.title("Correlation for Features for Asset_ID_" + str(id+1))
    plt.show()
